# %%
# Add relevant Jupyter notebook extensions 
# %load_ext autoreload 
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\\python312.zip', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\\DLLs', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\\Lib', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0', 'c:\\Users\\A User\\OneDrive\\Documents\\year3\\B1-scientific-coding-MT\\.venv', '', 'c:\\Users\\A User\\OneDrive\\Documents\\year3\\B1-scientific-coding-MT\\.venv\\Lib\\site-packages', 'c:\\Users\\A User\\OneDrive\\Documents\\year3\\B1-scientific-coding-MT\\.venv\\Lib\\site-packages\\win32', 'c:\\Users\\A User\\OneDrive\\Documents\\year3\\B1-scientific-coding-MT\\.venv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\A User\\OneDrive\\Documents\\year3\\B1-scientific-coding-MT\\.venv\\Lib\\site-packages\\Pythonwin', 'c:\\Users\\A User\\OneDrive\\Documents\\year3\\B1-scientific-coding-MT\\b1-scientific-coding-mt24', 'c:\\Users\\A User\\OneDrive\\Documents\\year3\\B1-scientific-coding-MT\\b1-scientific-coding-mt24', 'c:\\Users\\A User\\OneDrive\\Documents\\year3\\B1-scientific-coding-MT\\b1-scientific-coding-mt24', 'c:\\Users\\A User\\OneDrive\\Documents\\year3\\B1-scientific-coding-MT\\b1-scientific-coding-mt24', 'c:\\Users\\A User\\OneDrive\\Documents\\year3\\B1-scientific-coding-MT\\b1-scientific-coding-mt24', 'c:\\Users\\A User\\OneDrive\\Documents\\year3\\B1-scientific-coding-MT\\b1-scientific-coding-mt24']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
import sys 
import os 
sys.path.append(os.path.abspath('..'))
from uuv_mission.dynamic import Submarine, ClosedLoop, Mission
from uuv_mission.control import Controller 


sub = Submarine()
# Instantiate your controller (depending on your implementation)
control = Controller(KP=0.15, KD=0.6)
closed_loop = ClosedLoop(sub, control)
mission = Mission.from_csv("../data/mission.csv") # You must implement this method in the Mission class
trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
